# %% [markdown]
# <a href="https://colab.research.google.com/github/injaamam/Transcribe/blob/main/Transcribe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/openai/whisper.git
# !sudo apt update && sudo apt install ffmpeg
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-ao8tgt9q
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-ao8tgt9q
#   Resolved https://github.com/openai/whisper.git to commit c0d2f624c09dc18e709e37c2ad90c039a4eb72a2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.3/188.3 MB 8.1 MB/s eta 0:00:00
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803979 sha256=8136ba9f089f58d8839b48e38f4e699a2aed49846a87b4a1edd759595bf91b78
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hcuwu03j/wheels/c3/03/25/5e0ba78bc27a3a089f137c9f1d92fdfce16d06996c071a016c
# Successfully built openai-whisper
# ...
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# ...

# %%
# !whisper "x.mp3" --model base.en
# Out:
# 100%|████████████████████████████████████████| 139M/139M [00:01<00:00, 118MiB/s]
# /usr/local/lib/python3.12/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# [00:00.000 --> 00:26.000]  I've been reading books so old, the legends and the myths, Achilles and it's gone, Hercules and it's guess, Spiderman's control, and Batman with his fists, and clearly I don't see myself apart the list.
# [00:26.000 --> 00:45.000]  They say where you want to go, how much you want to risk, I'm not looking for somebody with some superhuman guilt, some superheroes, some fairy tale plays, just something like in time to somebody I can't guess.
# [00:45.000 --> 00:53.000]  I want something just like this.
# [00:54.000 --> 01:06.000]  I want something just like this.
# [01:06.000 --> 01:22.000]  I want something just like this, like this, like this
# ...

# %%
# To see all commands
# !whisper -h
# Out:
# usage: whisper [-h] [--model MODEL] [--model_dir MODEL_DIR] [--device DEVICE]
#                [--output_dir OUTPUT_DIR]
#                [--output_format {txt,vtt,srt,tsv,json,all}]
#                [--verbose VERBOSE] [--task {transcribe,translate}]
# ...
